# %%
from modules.odconv import ODConv2d
from mobilenetv2_fpn_od import MobileNetV2_dynamicFPN
import torch

# %%
MobileNetV2_dynamicFPN()
# Out:
# MobileNetV2_dynamicFPN(
#   (first_layer): Sequential(
#     (0): ConvBNReLU(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (inverted_residual_blocks): ModuleList(
#     (0): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(16, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(16, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 24, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(24, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 24, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 144, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(144, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 144, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(16, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(144, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 144, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 24, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(24, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 24, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 144, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(144, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 144, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(16, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(144, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 144, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(16, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(16, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(16, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 192, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(24, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(24, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(24, 64, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(24, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(24, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(24, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(24, 64, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(24, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(24, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(24, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(24, 64, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(24, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(24, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(24, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(384, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(24, 384, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(24, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 576, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(576, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(36, 576, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(36, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(36, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(576, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(36, 576, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(36, 96, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(36, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 576, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(576, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(36, 576, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(36, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(36, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(576, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(36, 576, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(36, 96, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(36, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 576, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(576, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(36, 576, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(36, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(36, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(576, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(36, 576, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(36, 160, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(36, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(160, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 960, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(960, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(60, 960, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(60, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(60, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(960, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(60, 960, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(60, 160, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(60, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(160, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 960, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(960, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(60, 960, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(60, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(60, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(960, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(60, 960, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(60, 160, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(60, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv): Sequential(
#           (0): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(160, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(16, 960, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#           (3): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(960, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(60, 960, kernel_size=(1, 1), stride=(1, 1))
#               (spatial_fc): Conv2d(60, 9, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(60, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU6(inplace=True)
#           (6): ODConv2d(
#             (attention): Attention(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc): Conv2d(960, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (channel_fc): Conv2d(60, 960, kernel_size=(1, 1), stride=(1, 1))
#               (filter_fc): Conv2d(60, 320, kernel_size=(1, 1), stride=(1, 1))
#               (kernel_fc): Conv2d(60, 4, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (7): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (last_layer): ConvBNReLU(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (output): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
#   (average_pool): AdaptiveAvgPool2d(output_size=1)
#   (top_layer): Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1))
#   (lateral_layers): ModuleList(
#     (0): Conv2d(24, 256, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#     (3): Conv2d(160, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (smooth_layers): ModuleList(
#     (0-4): 5 x Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=62720, out_features=1000, bias=True)
#   )
# )
